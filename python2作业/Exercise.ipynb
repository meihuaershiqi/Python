# %% [markdown]
# # 1. 实现一周的记账功能
# 首先记录输入的7天的收入，然后记录输入的7天的支出。
# 然后打印出以下内容：
# 7天的收入(list)
# 7天的支出(list)
# 每天的结余(dict)
# 最终的结余

# %%
income_list = []                                          # 七日收入（每日）
expenditure_list = []                                     # 七日支出（每日）
balance_dist = {}                                         # 每日结余
income_total = 0                                          # 七日总收入
expenditure_total = 0                                     # 七日总支出
print("请输入7天内的收入和支出：")                        # 用户输入默认大于0的整型数字
for i in range(1,8,1):
    print("第{0}天收入（元）：".format(i))
    income = int(input())
    income_total += income
    income_list.append(income)
    print("第{0}天支出（元）：".format(i))
    expenditure = int(input())
    expenditure_total += expenditure
    expenditure_list.append(expenditure)
    balance_dist[i] = income - expenditure

print("7天的总收入为（元）：{0}".format(income_total))
print("7天的总支出为（元）：{0}".format(expenditure_total))

balance_total = 0                                        # 最终结余
for i in range(7):
    print("第{0}天的结余为（元）：{1}".format(i+1,balance_dist[i+1]))
    balance_total += balance_dist[i+1]
print("最终结余为（元）：{0}".format(balance_total))
# Out:
# 请输入7天内的收入和支出：
# 第1天收入（元）：
# 100
# 第1天支出（元）：
# 10
# 第2天收入（元）：
# 100
# 第2天支出（元）：
# 10
# 第3天收入（元）：
# 100
# 第3天支出（元）：
# 10
# 第4天收入（元）：
# 100
# 第4天支出（元）：
# 10
# 第5天收入（元）：
# 100
# 第5天支出（元）：
# 10
# 第6天收入（元）：
# 1
# 第6天支出（元）：
# 1
# 第7天收入（元）：
# 100
# 第7天支出（元）：
# 30
# 7天的总收入为（元）：601
# 7天的总支出为（元）：81
# 第1天的结余为（元）：90
# 第2天的结余为（元）：90
# 第3天的结余为（元）：90
# 第4天的结余为（元）：90
# 第5天的结余为（元）：90
# 第6天的结余为（元）：0
# 第7天的结余为（元）：70
# 最终结余为（元）：520

# %% [markdown]
# # 2. 实现ATM机器
# 查询余额
# 存款
# 取款
# 退出

# %%
balance = 3000                                                                       #初始余额默认3000
print("请输入您需要的操作代码：\n1--查询余额\n2--存款\n3--取款\n4--退出")
while 1 :
    ope = int(input())                                                               #用户输入限定为（1，2，3，4）
    if ope not in (1,2,3,4) :
        print("请输入正确的代码：\n1--查询余额\n2--存款\n3--取款\n4--退出")
        continue
    elif ope == 1 :                                                                #存取款金额限定为100的正整数倍
        print("您当前余额为{0}元".format(balance))
    elif ope == 2 :                                                              
        print("请输入您的存款金额（元）--100的正整数倍：")
        sum = int(input())
        while sum < 0 or sum%100 != 0 :
            print("请输入正确的存款金额（元）--100的正整数倍：")
            sum = int(input())
        balance += sum
        print("存款{0}元成功！".format(sum))
    elif ope == 3 :
        print("请输入您的取款金额（元）--100的正整数倍：")
        sum = int(input())
        while sum < 0 or sum%100 != 0 :
            print("请输入正确的取款金额（元）--100的正整数倍：")
            sum = int(input())
        if balance >= sum :
            balance -= sum
            print("取款{0}元成功！".format(sum))
        else :
            print("余额不足，取款失败！")     
    else :
        print("欢迎下次使用！")
        break
    print("请继续：\n1--查询余额\n2--存款\n3--取款\n4--退出")
# Out:
# 请输入您需要的操作代码：
# 1--查询余额
# 2--存款
# 3--取款
# 4--退出
# 1
# 您当前余额为3000元
# 请继续：
# 1--查询余额
# 2--存款
# 3--取款
# 4--退出
# 2
# 请输入您的存款金额（元）--100的正整数倍：
# 300
# 存款300元成功！
# 请继续：
# 1--查询余额
# 2--存款
# 3--取款
# 4--退出
# 1
# 您当前余额为3300元
# 请继续：
# 1--查询余额
# 2--存款
# 3--取款
# 4--退出
# 2
# 请输入您的存款金额（元）--100的正整数倍：
# 30
# 请输入正确的存款金额（元）--100的正整数倍：
# 100
# 存款100元成功！
# 请继续：
# 1--查询余额
# 2--存款
# 3--取款
# 4--退出
# 1
# 您当前余额为3400元
# 请继续：
# 1--查询余额
# 2--存款
# 3--取款
# 4--退出
# 3
# 请输入您的取款金额（元）--100的正整数倍：
# 3
# 请输入正确的取款金额（元）--100的正整数倍：
# 2000
# 取款2000元成功！
# 请继续：
# 1--查询余额
# 2--存款
# 3--取款
# 4--退出
# 1
# 您当前余额为1400元
# 请继续：
# 1--查询余额
# 2--存款
# 3--取款
# 4--退出
# 3
# 请输入您的取款金额（元）--100的正整数倍：
# 2000
# 余额不足，取款失败！
# 请继续：
# 1--查询余额
# 2--存款
# 3--取款
# 4--退出
# 1
# 您当前余额为1400元
# 请继续：
# 1--查询余额
# 2--存款
# 3--取款
# 4--退出
# 4
# 欢迎下次使用！

# %% [markdown]
# # 3. 词汇表生成及统计
#
# 下面是一段[文本](http://baijiahao.baidu.com/s?id=1646569900805781240&wfr=spider&for=pc)：
#
# > 2019年十月一日上午，庆祝中华人民共和国成立70周年阅兵式在首都北京盛大举行，59个阅兵方阵，580台受阅装备，1.5万人的参阅队伍接受了全国人民的检阅。阅兵装备方队展示的武器装备皆为国产现役主战装备，40%为首次展示。其中近些年来广受全球关注的东风41洲际弹道导弹，巨浪二潜射弹道导弹，东风17高超音速武器系统终于揭幕亮剑，以"不怒自威"的形象向世界展示中国捍卫和平的意志与力量。相较于其他首度公开亮相的武器装备，这三款武器多年来传闻不断，备受关注，并因其"大国基石"的地位而被公众赋予特殊的期待，这三款武器装备实力究竟如何，又各自承担着怎样的历史"使命"呢？本报特约相关领域军事专家，为大家详细解读这三款彰显国威，震撼世界的国之重器。
#
# 经过分词后得到以下单词，通过空格分隔。
#
# ```
# text = '2019 年 十月 一日 上午 ， 庆祝 中华人民共和国 成立 70 周年 阅兵式 在 首都北京 盛大举行 ， 59 个 阅兵 方阵 ， 580 台受 阅 装备 ， 1.5 万人 的 参阅 队伍 接受 了 全国 人民 的 检阅 。 阅兵 装备 方队 展示 的 武器装备 皆 为 国产 现役 主战 装备 ， 40% 为 首次 展示 。 其中 近些年来 广受 全球 关注 的 东风 41 洲际 弹道导弹 ， 巨浪 二潜射 弹道导弹 ， 东风 17 高超音速 武器 系统 终于 揭幕 亮剑 ， 以 " 不怒 自威 " 的 形象 向 世界 展示 中国 捍卫 和平 的 意志 与 力量 。 相较 于 其他 首度 公开 亮相 的 武器装备 ， 这 三款 武器 多年 来 传闻 不断 ， 备受 关注 ， 并 因 其 " 大国 基石 " 的 地位 而 被 公众 赋予 特殊 的 期待 ， 这 三款 武器装备 实力 究竟 如何 ， 又 各自 承担 着 怎样 的 历史 " 使命 " 呢 ？ 本报 特约 相关 领域 军事 专家 ， 为 大家 详细 解读 这 三款 彰显 国威 ， 震撼 世界 的 国 之 重器 。'
# ```
#
# 将文本生成词汇表(单词list)，单词对应ID的dict，以及ID对应单词的dict。
# 将你的程序变成一个盒子，输入就是上面一段文本，盒子内部：首先将文本转换成单词列表，再得到统计的单词表(去重)，然后得到单词ID相互对应的字典。
# 效果如下：
#
# ```
# vocab = ['大家', '中国', '捍卫', ...]
# word2id = {'大家': 0, '中国': 1, '捍卫': 2, ...}
# id2word = {0: '大家', 1: '中国', 2: '捍卫', ...}
# ```

# %%
print("请输入文本信息：")
vocab_set = set (input().split(" "))
vocab = list(vocab_set)                              # 单词表(去重)
word2id = {}                                         # 单词对应ID的dict                               
id2word = {}                                         # ID对应单词的dict
for i in range(len(vocab)) :
    word2id[vocab[i]] = i
    id2word[i] = vocab[i]
print("\n\n\nvocab = {0}".format(vocab))
print("\n\n\nword2id = {0}".format(word2id))
print("\n\n\nid2word = {0}".format(id2word))
# Out:
# 请输入文本信息：
# 2019 年 十月 一日 上午 ， 庆祝 中华人民共和国 成立 70 周年 阅兵式 在 首都北京 盛大举行 ， 59 个 阅兵 方阵 ， 580 台受 阅 装备 ， 1.5 万人 的 参阅 队伍 接受 了 全国 人民 的 检阅 。 阅兵 装备 方队 展示 的 武器装备 皆 为 国产 现役 主战 装备 ， 40% 为 首次 展示 。 其中 近些年来 广受 全球 关注 的 东风 41 洲际 弹道导弹 ， 巨浪 二潜射 弹道导弹 ， 东风 17 高超音速 武器 系统 终于 揭幕 亮剑 ， 以 " 不怒 自威 " 的 形象 向 世界 展示 中国 捍卫 和平 的 意志 与 力量 。 相较 于 其他 首度 公开 亮相 的 武器装备 ， 这 三款 武器 多年 来 传闻 不断 ， 备受 关注 ， 并 因 其 " 大国 基石 " 的 地位 而 被 公众 赋予 特殊 的 期待 ， 这 三款 武器装备 实力 究竟 如何 ， 又 各自 承担 着 怎样 的 历史 " 使命 " 呢 ？ 本报 特约 相关 领域 军事 专家 ， 为 大家 详细 解读 这 三款 彰显 国威 ， 震撼 世界 的 国 之 重器 。
#
#
#
# vocab = ['历史', '主战', '广受', '并', '备受', '2019', '详细', '成立', '队伍', '首次', '以', '多年', '揭幕', '承担', '国', '不怒', '与', '东风', '终于', '彰显', '力量', '40%', '国产', '和平', '装备', '又', '上午', '的', '赋予', '，', '大国', '在', '武器', '全球', '使命', '。', '人民', '庆祝', '公开', '世界', '形象', '接受', '捍卫', '相较', '59', '现役', '不断', '阅兵式', '阅兵', '中国', '"', '17', '70', '周年', '相关', '实力', '解读', '之', '究竟', '盛大举行', '1.5', '首都北京', '特约', '台受', '了', '首度', '基石', '而', '期待', '方阵', '自威', '中华人民共和国', '弹道导弹', '这', '传闻', '检阅', '重器', '其他', '大家', '洲际', '三款', '万人', '？', '意志', '41', '系统', '近些年来', '地位', '着', '为', '如何', '十月', '本报', '被', '特殊', '震撼', '国威', '高超音速', '其中', '公众', '参阅', '军事', '呢', '领域', '来', '各自', '阅', '关注', '方队', '展示', '武器装备', '一日', '亮相', '专家', '全国', '皆', '其', '亮剑', '年', '二潜射', '巨浪', '向', '580', '怎样', '于', '因', '个']
#
#
#
# word2id = {'历史': 0, '主战': 1, '广受': 2, '并': 3, '备受': 4, '2019': 5, '详细': 6, '成立': 7, '队伍': 8, '首次': 9, '以': 10, '多年': 11, '揭幕': 12, '承担': 13, '国': 14, '不怒': 15, '与': 16, '东风': 17, '终于': 18, '彰显': 19, '力量': 20, '40%': 21, '国产': 22, '和平': 23, '装备': 24, '又': 25, '上午': 26, '的': 27, '赋予': 28, '，': 29, '大国': 30, '在': 31, '武器': 32, '全球': 33, '使命': 34, '。': 35, '人民': 36, '庆祝': 37, '公开': 38, '世界': 39, '形象': 40, '接受': 41, '捍卫': 42, '相较': 43, '59': 44, '现役': 45, '不断': 46, '阅兵式': 47, '阅兵': 48, '中国': 49, '"': 50, '17': 51, '70': 52, '周年': 53, '相关': 54, '实力': 55, '解读': 56, '之': 57, '究竟': 58, '盛大举行': 59, '1.5': 60, '首都北京': 61, '特约': 62, '台受': 63, '了': 64, '首度': 65, '基石': 66, '而': 67, '期待': 68, '方阵': 69, '自威': 70, '中华人民共和国': 71, '弹道导弹': 72, '这': 73, '传闻': 74, '检阅': 75, '重器': 76, '其他': 77, '大家': 78, '洲际': 79, '三款': 80, '万人': 81, '？': 82, '意志': 83, '41': 84, '系统': 85, '近些年来': 86, '地位': 87, '着': 88, '为': 89, '如何': 90, '十月': 91, '本报': 92, '被': 93, '特殊': 94, '震撼': 95, '国威': 96, '高超音速': 97, '其中': 98, '公众': 99, '参阅': 100, '军事': 101, '呢': 102, '领域': 103, '来': 104, '各自': 105, '阅': 106, '关注': 107, '方队': 108, '展示': 109, '武器装备': 110, '一日': 111, '亮相': 112, '专家': 113, '全国': 114, '皆': 115, '其': 116, '亮剑': 117, '年': 118, '二潜射': 119, '巨浪': 120, '向': 121, '580': 122, '怎样': 123, '于': 124, '因': 125, '个': 126}
#
#
#
# id2word = {0: '历史', 1: '主战', 2: '广受', 3: '并', 4: '备受', 5: '2019', 6: '详细', 7: '成立', 8: '队伍', 9: '首次', 10: '以', 11: '多年', 12: '揭幕', 13: '承担', 14: '国', 15: '不怒', 16: '与', 17: '东风', 18: '终于', 19: '彰显', 20: '力量', 21: '40%', 22: '国产', 23: '和平', 24: '装备', 25: '又', 26: '上午', 27: '的', 28: '赋予', 29: '，', 30: '大国', 31: '在', 32: '武器', 33: '全球', 34: '使命', 35: '。', 36: '人民', 37: '庆祝', 38: '公开', 39: '世界', 40: '形象', 41: '接受', 42: '捍卫', 43: '相较', 44: '59', 45: '现役', 46: '不断', 47: '阅兵式', 48: '阅兵', 49: '中国', 50: '"', 51: '17', 52: '70', 53: '周年', 54: '相关', 55: '实力', 56: '解读', 57: '之', 58: '究竟', 59: '盛大举行', 60: '1.5', 61: '首都北京', 62: '特约', 63: '台受', 64: '了', 65: '首度', 66: '基石', 67: '而', 68: '期待', 69: '方阵', 70: '自威', 71: '中华人民共和国', 72: '弹道导弹', 73: '这', 74: '传闻', 75: '检阅', 76: '重器', 77: '其他', 78: '大家', 79: '洲际', 80: '三款', 81: '万人', 82: '？', 83: '意志', 84: '41', 85: '系统', 86: '近些年来', 87: '地位', 88: '着', 89: '为', 90: '如何', 91: '十月', 92: '本报', 93: '被', 94: '特殊', 95: '震撼', 96: '国威', 97: '高超音速', 98: '其中', 99: '公众', 100: '参阅', 101: '军事', 102: '呢', 103: '领域', 104: '来', 105: '各自', 106: '阅', 107: '关注', 108: '方队', 109: '展示', 110: '武器装备', 111: '一日', 112: '亮相', 113: '专家', 114: '全国', 115: '皆', 116: '其', 117: '亮剑', 118: '年', 119: '二潜射', 120: '巨浪', 121: '向', 122: '580', 123: '怎样', 124: '于', 125: '因', 126: '个'}
